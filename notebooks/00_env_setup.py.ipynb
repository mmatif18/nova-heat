# %%
# %sql

-- CREATE DATABASES TO SIMULATE MEDALLION ARCHITECTURE
CREATE DATABASE IF NOT EXISTS nova_heat_bronze;
CREATE DATABASE IF NOT EXISTS nova_heat_silver;
CREATE DATABASE IF NOT EXISTS nova_heat_gold;

# %%
# %sql
SHOW DATABASES LIKE 'nova_heat*';
